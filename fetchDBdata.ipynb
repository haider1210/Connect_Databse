# %% [markdown]
# # Get VTL from model_id

# %%
from fetchdata import OracleDatabase 
from sqlalchemy import create_engine, text

# Replace this with your actual connection string
connection_string = 'oracle://HCMP_CRM_DEV:***password****@10.16........:1535/hc.....v'

# Create an instance of OracleDatabase
oracle_db = OracleDatabase(connection_string)

# %%
model_id=2043

# %% [markdown]
# ##### GET Table

# %%
write_query = "SELECT * FROM om_config_command_templates"
result_df = oracle_db.execute_query(text(write_query))
result_df
# Out:
#      model_id                                   command_template  \
# 0      1133.0  {\n  "group": {\n    "deleteport-1": "openstac...
# 1      1129.0  { \n  "group": { \n    "deletesubnet-1": "open...
# 2      1136.0  {\n  "group": {\n    "changebootable-1": "open...
# 3      1134.0  {\r\n  "group": {\r\n    "rosdeletestaticroute...
# 4      1128.0  { \n  "group": { \n    "deletenetwork-1": "ope...
# ..        ...                                                ...
# 981    2040.0  {\r\n  "group": {\r\n    "azurecluster-1": "az...
# 982    2043.0  {\n  "group": {\n    "azurecluster-1": "azurec...
# 983    6028.0  {\r\n  "group": {\r\n    "azurecluster-1": "az...
# 984    2044.0  {\n  "group": {\n    "azurecluster-1": "azurec...
# 985    2053.0  \r\n\r\n\r\n{\r\n "group": {\r\n\t  #if(${tran...
#
#      transaction_type_id    id    provider_sync_code enabled status  \
# 0                    NaN     1  ros_incremental_sync       Y      A
# 1                    NaN     3  ros_incremental_sync       Y      A
# 2                    NaN     5  ros_incremental_sync       Y      A
# 3                    NaN     6  ros_incremental_sync       Y      A
# 4                    NaN    10  ros_incremental_sync       Y      A
# ..                   ...   ...                   ...     ...    ...
# 981                  NaN  2040                  None       Y      A
# 982                  NaN  2043                  None       Y      A
# 983                  NaN  6028                  None       Y      A
# 984                  NaN  2044                  None       Y      A
# 985                  NaN  2053                  None       Y      A
#
#      provider_id
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 981          NaN
# 982          NaN
# 983          NaN
# 984          NaN
# 985          NaN
#
# [986 rows x 8 columns]

# %% [markdown]
# ### GET VTL

# %%
from IPython.display import HTML
write_query = "SELECT * FROM om_config_command_templates where model_id=:model_id"
result_df = oracle_db.execute_queryVTL(text(write_query).bindparams(model_id=model_id))
styled_output = f"<pre style='cursor: text;' onclick='window.getSelection().selectAllChildren(this);'>{result_df}</pre>"

# %% [markdown]
# ##### output

# %%
HTML(styled_output)
# Out:
# <pre style='cursor: text;' onclick='window.getSelection().selectAllChildren(this);'>{
#   "group": {
#     "azurecluster-1": "azurecliProvider.microsoftCLI"
#   },
#   "commands": {
#     #if(${transaction.order_lines[0].node.configurations.config_attributes.utility}=="Retrieve_the_List_of_database_migrations_attached_to_the_service")
#       "group.azurecluster-1.cmd": "datamigration sql-service list-migration",
# 	  "group.azurecluster-1.flags.--name": "${transaction.order_lines[0].node.configurations.config_attributes.name}",
#       "group.azurecluster-1.flags.--resource-group": "${transaction.order_lines[0].node.configurations.config_attributes.resourcegroup}",
#     #elseif(${transaction.order_lines[0].node.configurations.config_attributes.utility}=="Retrieve_the_List_of_Authentication_Keys_for_Self_Hosted_Integration_Runtime")
# 	  "group.azurecluster-1.cmd": "datamigration sql-service list-auth-key",
#       "group.azurecluster-1.flags.--n": "${transaction.order_lines[0].node.configurations.config_attributes.name}",
#       "group.azurecluster-1.flags.-g": "${transaction.order_lines[0].node.configurations.config_attributes.resourcegroup}",
# 	#elseif(${transaction.order_lines[0].node.configurations.config_attributes.utility}=="Retrieve_all_Database_Migration_Services_in_the_resource_group_and_subscription")
# 	  "group.azurecluster-1.cmd": "datamigration sql-service list",
#       "group.azurecluster-1.flags.-g": "${transaction.order_lines[0].node.configurations.config_attributes.resourcegroup}",
#
# 	#elseif(${transaction.order_lines[0].node.configurations.config_attributes.utility}=="Delete_Database_Migration_Service")
# 	  "group.azurecluster-1.cmd": "datamigration sql-service delete",
#       "group.azurecluster-1.flags.--n": "${transaction.order_lines[0].node.configurations.config_attributes.name}",
#       "group.azurecluster-1.flags.-g": "${transaction.order_lines[0].node.configurations.config_attributes.resourcegroup}",
# 	  "group.azurecluster-1.flags.--yes": "-y",
#
# 	#elseif(${transaction.order_lines[0].node.configurations.config_attributes.utility}=="Create_Database_Migration_Service")
# 	  "group.azurecluster-1.cmd": "datamigration sql-service create",
# 	  "group.azurecluster-1.flags.--n": "${transaction.order_lines[0].node.configurations.config_attributes.name}",
#       "group.azurecluster-1.flags.-g": "${transaction.order_lines[0].node.configurations.config_attributes.resourcegroup}",
#       "group.azurecluster-1.args.--yes",
#
#
# 	#end
#
#
#   },
#   "response": {
#     "out": {
#       "quantity": 1,
#       "details": [
#         {
#           "id": "%AA%raw[ 'azurecluster-1' ].response.id%AA%",
#           "type": "Microsoft.Compute/createimage",
#           "resourcegroup": "%AA%raw[ 'azurecluster-1' ].response.resourcegroup%AA%"
#         }
#       ]
#       }
#     }
# }
#
# </pre>
